# %% [markdown]
# # K Means Clustering

# %% [markdown]
# Importing the required libraries

# %%
import pandas as pd

# %% [markdown]
# Calculating distance between two datapoints

# %%
# Function to return the distance between two datapoints
def dist(a, b):
	s = 0
	for i in range(len(a)):
		s += abs(a[i] - b[i])
	return s

# %% [markdown]
# Calculating Mean

# %%
# Function to return the mean of set of datapoints
def mean(a):
	m = []
	for i in range(len(a[0])):
		s = 0
		for j in range(len(a)):
			s += a[j][i]
		m.append(s / len(a))
	return m

# %% [markdown]
# One Hot Encoding to make the dataset ready to be fed to the K Means Clustering algorithm

# %%
# Function to perform One Hot Encoding that is binarization of each column
# This function makes the dataset ready to be fed to the KMeans Clustering algorithm
def OneHotEncoding(X):
	global onehotX
	onehotX = []
	for i in range(len(X)):
		tmp1 = [0] * 6
		for j in range(6): 
			if X[i][0].lower() == season[j].lower():
				tmp1[j] = 1
				break
		tmp2 = [0] * 6
		for j in range(6): 
			if X[i][1].lower() == soil[j].lower():
				tmp2[j] = 1
				break
		tmp3 = [0] * 5
		for j in range(5): 
			if X[i][2].lower() == rainfall[j].lower():
				tmp3[j] = 1
				break

		tmp = []
		for j in tmp1: tmp.append(j)
		for j in tmp2: tmp.append(j)
		for j in tmp3: tmp.append(j)
		onehotX.append(tuple(tmp))

# %% [markdown]
# K Means Clustering Algorithm

# %%
# Function that implements K_Means Clustering Algorithm
# Returns a dictionary where key is the datapoint and value is the cluster it belongs to
def K_Means(onehotX):
	global m
	rndm =  [8, 3, 73, 30, 51, 71, 17, 58, 19, 74, 21, 46]
	for i in rndm:
		m.append(onehotX[i])
	count = 0
	for I in range(100):
		count -= -1
		c = {}
		for i in range(len(onehotX)):
			ind = 0
			mn = 20
			for j in range(12):
				if dist(onehotX[i], m[j]) < mn:
					mn = dist(onehotX[i], m[j])
					ind = j
			c[onehotX[i]] = ind
		m2 = []
		for i in range(12):
			ttt = []
			for j in c:
				if c[j] == i: ttt.append(j)
			m2.append(mean(ttt))
		if m2 == m: break
		m = m2
	return c

# %% [markdown]
# Reading the data and calling the required functions to perform K Means Clustering

# %%
DF = pd.read_csv('../data/7_Preprocess_Final.csv')

df = DF[['Season', 'Soil Type', 'Rainfall_Disc']]

DF = DF[['Season', 'Crop', 'Soil Type', 'Rainfall_Disc', 'Yield_Disc']]

X = df.iloc[:, : ].values

df = DF[['Crop', 'Yield_Disc']]
cr = df.iloc[:, : ].values

# cpp is a list of list where inner list contains crop and yield of each row
cpp = []
for i in cr: cpp.append(i.tolist())

# ans contains list which contains each element of cpp and the cluster it belongs to
ans = []

# crop is a list of all unique crops in the dataset
crop = DF['Crop'].unique()

# season is a list of all unique seasons in the dataset
season = DF['Season'].unique()

# soil is a list of all unique types of soil in the dataset
soil = DF['Soil Type'].unique()

# rainfall is a list of all unique types of rainfall in the dataset
rainfall = DF['Rainfall_Disc'].unique()

# onehotX is a list. It is basically One Hot Encoding where each column is binarized to apply KMeans Clustering algorithm
onehotX = []

OneHotEncoding(X)

onehotX2 = []
for i in onehotX: onehotX2.append(i)

onehotX = list(set(onehotX))

clscropyield = []

# m contains the final mean of each cluster
m = []

# c is a dictionary where the key is the datapoint and the value is the cluster it belongs to
c = K_Means(onehotX)


for i in range(len(onehotX2)):
	ans.append([cpp[i], c[onehotX2[i]]])

rain = ['Very_High', 'High', 'Medium', 'Low', 'Very_Low']

# %% [markdown]
# Taking input from the user and providing the crops that are most suitable to be grown based on the input conditions

# %%
# Taking user input and checking for invalid inputs
print("Please provide the conditions so that we can suggest suitable crops to grow")
print()	
print("Enter 1 to 6 corresponding to your choice of season:\n1 Kharif\n2 Summer\n3 Whole Year\n4 Rabi\n5 Winter\n6 Autumn")
tempo = input()
if len(tempo) > 1 or tempo == '':
	print("Invalid Input")
	exit()
if ord(tempo) < 49 or ord(tempo) > 54:
	print("Invalid Input")
	exit()
inp_season = season[int(tempo) - 1]

print("\nEnter 1 to 6 corresponding to your choice of soil type:\n1 Alluvial\n2 Black\n3 Red\n4 Mountain\n5 Laterite\n6 Arid")
tempo = input()
if len(tempo) > 1 or tempo == '':
	print("Invalid Input")
	exit()
if ord(tempo) < 49 or ord(tempo) > 54:
	print("Invalid Input")
	exit()
inp_soil = soil[int(tempo) - 1]

print("\nEnter 1 to 5 corresponding to your choice of rainfall:\n1 Very_High\n2 High\n3 Medium\n4 Low\n5 Very_Low")
tempo = input()
if len(tempo) > 1 or tempo == '':
	print("Invalid Input")
	exit()
if ord(tempo) < 49 or ord(tempo) > 53:
	print("Invalid Input")
	exit()
inp_rainfall = rain[int(tempo) - 1]
print()


Y = [[inp_season, inp_soil, inp_rainfall]]

OneHotEncoding(Y)


# Calculating the cluster which the input points belong to
mn = 20
for i in range(12):
	if dist(onehotX[0], m[i]) < mn:
		mn = dist(onehotX[0], m[i])
		predicted_class = i


# Each of the five lists below contains the crops with the particular yield as indicated in the name
very_high_yield = []
high_yield = []
medium_yield = []
low_yield = []
very_low_yield = []

for i in ans:
	if i[1] == predicted_class:	
		if i[0][1] == 'Very_High': very_high_yield.append(i[0][0])
		elif i[0][1] == 'High': high_yield.append(i[0][0])
		elif i[0][1] == 'Medium': medium_yield.append(i[0][0])
		elif i[0][1] == 'Low': low_yield.append(i[0][0])
		elif i[0][1] == 'Very_Low': very_low_yield.append(i[0][0])

very_high_yield = set(very_high_yield)

high_yield = set(high_yield)

medium_yield = set(medium_yield)

very_low_yield = set(very_low_yield)

low_yield = set(low_yield)



# The crops with very high yield are only those which never give very low yield or low yield and so.
# This step more or less removes the possibility that high yield of the crop was because of artificial water supply
very_high_yield -= very_low_yield
very_high_yield -= low_yield
very_high_yield -= high_yield
very_high_yield -= medium_yield

high_yield -= very_low_yield
high_yield -= medium_yield


# Output
print("The following crop(s) give(s) a Very High Yield:")
print(very_high_yield)
print()

if len(high_yield) > 0:
	print("The following crop(s) give(s) High Yield as well:")
	print(high_yield)
	print()

print("The following crop(s) give(s) Medium Yield:")
print(medium_yield)
print()
# Out:
# Please provide the conditions so that we can suggest suitable crops to grow
#
# Enter 1 to 6 corresponding to your choice of season:
# 1 Kharif
# 2 Summer
# 3 Whole Year
# 4 Rabi
# 5 Winter
# 6 Autumn
# 1
#
# Enter 1 to 6 corresponding to your choice of soil type:
# 1 Alluvial
# 2 Black
# 3 Red
# 4 Mountain
# 5 Laterite
# 6 Arid
# 1
#
# Enter 1 to 5 corresponding to your choice of rainfall:
# 1 Very_High
# 2 High
# 3 Medium
# 4 Low
# 5 Very_Low
# 5
#
# The following crop(s) give(s) a Very High Yield:
# {'Sugarcane', 'Pineapple', 'Grapes', 'Tapioca', 'Brinjal', 'Atcanut (Raw)', 'Jack Fruit'}
#
# The following crop(s) give(s) High Yield as well:
# {'Bhindi'}
#
# The following crop(s) give(s) Medium Yield:
# {'other oilseeds', 'Gram', 'Arhar/Tur', 'Dry ginger', 'Sunflower', 'Orange', 'Papaya', 'Onion', 'Tobacco', 'Varagu', 'Cotton(lint)', 'Jute', 'Ragi', 'Rapeseed &Mustard', 'Pome Fruit', 'Barley', 'Castor seed', 'Arecanut', 'Wheat', 'Bajra', 'Maize', 'Sweet potato', 'Soyabean', 'Mango', 'Safflower', 'Mesta', 'Other  Rabi pulses', 'Garlic', 'Arcanut (Processed)', 'Urad', 'Coconut ', 'Masoor', 'Other Fresh Fruits', 'Small millets', 'Moong(Green Gram)', 'Groundnut', 'Paddy', 'Rice', 'Jowar', 'Dry chillies', 'Turmeric'}

# %%
ans
# Out:
# [[['Cashewnut', 'Low'], 5],
#  [['Maize', 'Low'], 0],
#  [['Cotton(lint)', 'Very_Low'], 11],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Urad', 'Very_Low'], 7],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Linseed', 'Very_Low'], 11],
#  [['Sunflower', 'Very_Low'], 11],
#  [['Wheat', 'Medium'], 4],
#  [['Coconut ', 'Very_High'], 5],
#  [['Ginger', 'Very_High'], 9],
#  [['Tobacco', 'Very_Low'], 3],
#  [['Urad', 'Very_Low'], 11],
#  [['Other  Rabi pulses', 'Low'], 4],
#  [['Dry chillies', 'Very_High'], 5],
#  [['Maize', 'Very_High'], 11],
#  [['Wheat', 'Low'], 8],
#  [['Urad', 'Very_Low'], 7],
#  [['Rice', 'Medium'], 7],
#  [['Groundnut', 'Low'], 2],
#  [['Bajra', 'Medium'], 9],
#  [['Grapes', 'Very_High'], 2],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Mesta', 'Very_High'], 11],
#  [['Gram', 'Low'], 4],
#  [['Urad', 'Very_Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 10],
#  [['Sunflower', 'Very_Low'], 10],
#  [['Onion', 'Very_High'], 2],
#  [['Black pepper', 'Very_Low'], 5],
#  [['Sunflower', 'Very_Low'], 0],
#  [['Potato', 'Very_High'], 2],
#  [['Sesamum', 'Very_Low'], 0],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Groundnut', 'Low'], 7],
#  [['Ragi', 'Low'], 10],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Turmeric', 'Medium'], 5],
#  [['Black pepper', 'Medium'], 1],
#  [['Moong(Green Gram)', 'Low'], 1],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Medium'], 4],
#  [['Ragi', 'Medium'], 7],
#  [['Wheat', 'Low'], 8],
#  [['Peas & beans (Pulses)', 'Medium'], 4],
#  [['Tapioca', 'Very_High'], 5],
#  [['Soyabean', 'Low'], 10],
#  [['Urad', 'Low'], 3],
#  [['Bajra', 'Low'], 9],
#  [['Maize', 'Very_High'], 10],
#  [['Dry chillies', 'Very_Low'], 10],
#  [['Arecanut', 'Low'], 5],
#  [['Niger seed', 'Very_Low'], 10],
#  [['Rice', 'Very_High'], 0],
#  [['Potato', 'Very_High'], 7],
#  [['Gram', 'Low'], 4],
#  [['Mesta', 'Very_High'], 9],
#  [['Groundnut', 'Medium'], 10],
#  [['Sunflower', 'Low'], 10],
#  [['Groundnut', 'Low'], 9],
#  [['Rice', 'Very_High'], 11],
#  [['Linseed', 'Low'], 4],
#  [['Potato', 'Very_High'], 2],
#  [['Cotton(lint)', 'Low'], 2],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Barley', 'Medium'], 3],
#  [['Rice', 'Low'], 7],
#  [['Onion', 'High'], 4],
#  [['Maize', 'High'], 11],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Arhar/Tur', 'Very_Low'], 9],
#  [['Rice', 'Very_High'], 11],
#  [['Arhar/Tur', 'Very_Low'], 6],
#  [['Tobacco', 'Very_High'], 7],
#  [['Coriander', 'Very_Low'], 1],
#  [['Rice', 'Medium'], 0],
#  [['Sugarcane', 'Very_High'], 9],
#  [['Guar seed', 'Low'], 9],
#  [['Moong(Green Gram)', 'Low'], 11],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Sesamum', 'Very_Low'], 11],
#  [['Potato', 'Very_High'], 5],
#  [['Sunflower', 'Medium'], 4],
#  [['Turmeric', 'Medium'], 2],
#  [['Tobacco', 'Very_High'], 4],
#  [['Dry chillies', 'Low'], 4],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Coconut ', 'Very_High'], 1],
#  [['Khesari', 'Very_Low'], 4],
#  [['Arhar/Tur', 'Low'], 10],
#  [['Arhar/Tur', 'Medium'], 2],
#  [['Sesamum', 'Very_Low'], 0],
#  [['Black pepper', 'High'], 7],
#  [['Rice', 'High'], 9],
#  [['Maize', 'High'], 9],
#  [['Maize', 'High'], 3],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Potato', 'Medium'], 4],
#  [['Groundnut', 'Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Sweet potato', 'Low'], 4],
#  [['Sunflower', 'Low'], 11],
#  [['Turmeric', 'Very_High'], 7],
#  [['Soyabean', 'Very_Low'], 10],
#  [['Onion', 'Very_High'], 1],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Ragi', 'Very_Low'], 7],
#  [['Small millets', 'Low'], 11],
#  [['Barley', 'Very_High'], 8],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Castor seed', 'Very_Low'], 9],
#  [['Urad', 'Very_Low'], 1],
#  [['Dry chillies', 'Very_High'], 7],
#  [['Groundnut', 'Very_Low'], 10],
#  [['Groundnut', 'Low'], 7],
#  [['Sesamum', 'Low'], 10],
#  [['Tapioca', 'Very_High'], 11],
#  [['Maize', 'Medium'], 4],
#  [['Maize', 'Medium'], 10],
#  [['Jowar', 'Low'], 10],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Rapeseed &Mustard', 'Medium'], 4],
#  [['Groundnut', 'Low'], 7],
#  [['Sesamum', 'Very_Low'], 0],
#  [['Onion', 'Very_High'], 5],
#  [['Garlic', 'Medium'], 1],
#  [['Cotton(lint)', 'Low'], 10],
#  [['Urad', 'Very_Low'], 9],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Snak Guard', 'Very_Low'], 7],
#  [['Coriander', 'Very_Low'], 4],
#  [['Banana', 'Very_High'], 5],
#  [['Castor seed', 'Very_Low'], 9],
#  [['Maize', 'Low'], 7],
#  [['Small millets', 'Low'], 9],
#  [['Garlic', 'Very_High'], 4],
#  [['Barley', 'High'], 4],
#  [['Masoor', 'Low'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Maize', 'Low'], 7],
#  [['Garlic', 'Very_High'], 4],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Other  Rabi pulses', 'Very_Low'], 7],
#  [['Coriander', 'Very_Low'], 5],
#  [['Rice', 'Low'], 7],
#  [['Niger seed', 'Very_Low'], 2],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Ragi', 'Medium'], 11],
#  [['Banana', 'Very_High'], 7],
#  [['Onion', 'Very_High'], 4],
#  [['Arecanut', 'Low'], 5],
#  [['Arecanut', 'Low'], 5],
#  [['Guar seed', 'Very_Low'], 4],
#  [['Maize', 'Medium'], 9],
#  [['Groundnut', 'Low'], 10],
#  [['Jowar', 'Very_Low'], 7],
#  [['Potato', 'Very_High'], 7],
#  [['Dry chillies', 'Very_High'], 1],
#  [['Barley', 'Low'], 8],
#  [['Masoor', 'Medium'], 8],
#  [['Sunflower', 'Low'], 4],
#  [['Dry ginger', 'Medium'], 11],
#  [['Rice', 'High'], 1],
#  [['Barley', 'High'], 4],
#  [['Other Kharif pulses', 'Very_Low'], 10],
#  [['Bajra', 'Medium'], 10],
#  [['Cotton(lint)', 'Medium'], 6],
#  [['Rice', 'High'], 9],
#  [['Jowar', 'Very_High'], 11],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Rice', 'Medium'], 1],
#  [['Arhar/Tur', 'Very_Low'], 9],
#  [['Peas & beans (Pulses)', 'Very_Low'], 7],
#  [['Wheat', 'Medium'], 7],
#  [['Onion', 'Very_High'], 5],
#  [['Jowar', 'Very_Low'], 11],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Jute', 'Very_High'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Snak Guard', 'Very_Low'], 5],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Sunflower', 'Low'], 3],
#  [['Masoor', 'Very_Low'], 3],
#  [['Banana', 'Very_High'], 3],
#  [['Wheat', 'High'], 3],
#  [['Sunflower', 'Very_Low'], 8],
#  [['Snak Guard', 'Very_Low'], 5],
#  [['Bajra', 'Low'], 9],
#  [['Peas & beans (Pulses)', 'Medium'], 4],
#  [['Sunflower', 'Very_Low'], 10],
#  [['Groundnut', 'Low'], 11],
#  [['Tobacco', 'Very_High'], 4],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Maize', 'High'], 1],
#  [['Jute', 'Very_High'], 9],
#  [['Arecanut', 'Very_High'], 5],
#  [['Dry ginger', 'Medium'], 9],
#  [['Masoor', 'Very_Low'], 2],
#  [['Rapeseed &Mustard', 'Low'], 8],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Rice', 'High'], 9],
#  [['Soyabean', 'Low'], 10],
#  [['Sunflower', 'Very_Low'], 10],
#  [['Sunflower', 'Medium'], 9],
#  [['Dry ginger', 'Very_Low'], 10],
#  [['Gram', 'Low'], 4],
#  [['Barley', 'High'], 4],
#  [['Tapioca', 'Very_High'], 1],
#  [['Groundnut', 'Medium'], 0],
#  [['Onion', 'Very_High'], 11],
#  [['Gram', 'Low'], 4],
#  [['Arhar/Tur', 'Very_Low'], 10],
#  [['Dry ginger', 'Very_High'], 11],
#  [['Masoor', 'Very_Low'], 8],
#  [['Horse-gram', 'Very_Low'], 10],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Onion', 'Very_High'], 2],
#  [['Rice', 'Very_High'], 7],
#  [['Rice', 'Low'], 10],
#  [['Urad', 'Low'], 1],
#  [['Maize', 'Very_High'], 11],
#  [['Coconut ', 'Very_High'], 1],
#  [['Masoor', 'Very_Low'], 7],
#  [['Banana', 'Very_High'], 1],
#  [['Dry chillies', 'Medium'], 7],
#  [['Urad', 'Very_Low'], 1],
#  [['Niger seed', 'Very_Low'], 10],
#  [['Wheat', 'Very_High'], 3],
#  [['Peas & beans (Pulses)', 'High'], 4],
#  [['Arhar/Tur', 'Very_Low'], 2],
#  [['Rapeseed &Mustard', 'High'], 4],
#  [['Cardamom', 'Very_Low'], 5],
#  [['Rice', 'Medium'], 9],
#  [['Tapioca', 'Very_High'], 1],
#  [['Urad', 'Low'], 9],
#  [['Maize', 'Very_High'], 1],
#  [['Other Kharif pulses', 'Very_Low'], 11],
#  [['Urad', 'Low'], 11],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Cotton(lint)', 'Low'], 11],
#  [['Snak Guard', 'Very_Low'], 5],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Rice', 'Very_High'], 11],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Maize', 'High'], 7],
#  [['Barley', 'Very_High'], 4],
#  [['Garlic', 'Very_High'], 5],
#  [['Peas & beans (Pulses)', 'Low'], 8],
#  [['Dry chillies', 'Low'], 5],
#  [['Cotton(lint)', 'High'], 11],
#  [['Banana', 'Very_High'], 5],
#  [['Jute', 'Very_High'], 9],
#  [['Other Cereals & Millets', 'Low'], 8],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Onion', 'Very_High'], 2],
#  [['Tobacco', 'Very_High'], 4],
#  [['Linseed', 'Very_Low'], 8],
#  [['Bajra', 'Medium'], 9],
#  [['Mesta', 'Very_High'], 9],
#  [['Gram', 'Low'], 4],
#  [['Rice', 'High'], 9],
#  [['Rice', 'High'], 0],
#  [['Bajra', 'Low'], 9],
#  [['Peas & beans (Pulses)', 'Low'], 4],
#  [['Other Kharif pulses', 'Low'], 9],
#  [['Bajra', 'Low'], 9],
#  [['Other Vegetables', 'Very_Low'], 7],
#  [['Groundnut', 'Very_High'], 11],
#  [['Bajra', 'Low'], 10],
#  [['Sesamum', 'Low'], 10],
#  [['Urad', 'Very_Low'], 9],
#  [['Rice', 'High'], 0],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Maize', 'Medium'], 3],
#  [['Banana', 'Very_High'], 5],
#  [['Other Fresh Fruits', 'High'], 5],
#  [['Small millets', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Very_Low'], 7],
#  [['Groundnut', 'Very_Low'], 11],
#  [['Dry chillies', 'High'], 11],
#  [['Peas & beans (Pulses)', 'Medium'], 4],
#  [['Maize', 'Very_High'], 11],
#  [['Cotton(lint)', 'Low'], 10],
#  [['Potato', 'Very_High'], 4],
#  [['Banana', 'Very_High'], 5],
#  [['Banana', 'Very_High'], 6],
#  [['Maize', 'Very_High'], 10],
#  [['Ragi', 'Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Arhar/Tur', 'Low'], 10],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Maize', 'Very_Low'], 11],
#  [['Rapeseed &Mustard', 'Very_Low'], 4],
#  [['Turmeric', 'Very_High'], 5],
#  [['Ragi', 'Very_Low'], 7],
#  [['Masoor', 'Very_Low'], 4],
#  [['Masoor', 'Very_Low'], 8],
#  [['Jute', 'Medium'], 10],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Other Kharif pulses', 'Very_Low'], 9],
#  [['Banana', 'Very_High'], 5],
#  [['Bajra', 'Medium'], 9],
#  [['Gram', 'Low'], 8],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Dry chillies', 'Low'], 9],
#  [['Mesta', 'Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Rice', 'Low'], 10],
#  [['Coriander', 'Very_Low'], 5],
#  [['Urad', 'Very_Low'], 3],
#  [['Dry chillies', 'Very_Low'], 1],
#  [['Jowar', 'Very_High'], 7],
#  [['Linseed', 'Very_Low'], 8],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Masoor', 'Low'], 4],
#  [['Maize', 'Low'], 7],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Sunflower', 'Low'], 9],
#  [['Bajra', 'Low'], 7],
#  [['Rice', 'Very_Low'], 7],
#  [['Rice', 'High'], 1],
#  [['Dry ginger', 'Very_High'], 9],
#  [['Castor seed', 'Very_Low'], 10],
#  [['Wheat', 'Low'], 8],
#  [['Paddy', 'Very_High'], 0],
#  [['Coriander', 'Low'], 5],
#  [['Dry chillies', 'Low'], 9],
#  [['Maize', 'Very_High'], 7],
#  [['Groundnut', 'Medium'], 0],
#  [['Gram', 'Medium'], 4],
#  [['Jowar', 'Low'], 9],
#  [['Arecanut', 'Medium'], 8],
#  [['Rapeseed &Mustard', 'Very_Low'], 8],
#  [['Ragi', 'Very_High'], 11],
#  [['Bajra', 'Very_Low'], 6],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Bajra', 'Low'], 10],
#  [['Small millets', 'Low'], 11],
#  [['Small millets', 'Very_Low'], 10],
#  [['Dry chillies', 'Medium'], 7],
#  [['Black pepper', 'Low'], 5],
#  [['Groundnut', 'Low'], 9],
#  [['other oilseeds', 'Very_Low'], 10],
#  [['Other  Rabi pulses', 'Low'], 7],
#  [['Sunflower', 'Very_Low'], 0],
#  [['Potato', 'Very_High'], 1],
#  [['Rice', 'Low'], 9],
#  [['Masoor', 'Very_Low'], 4],
#  [['Niger seed', 'Very_Low'], 9],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Mesta', 'Very_Low'], 2],
#  [['Barley', 'Low'], 7],
#  [['Other Kharif pulses', 'Low'], 10],
#  [['Barley', 'Very_High'], 4],
#  [['Small millets', 'Very_Low'], 10],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Barley', 'High'], 4],
#  [['Castor seed', 'Very_Low'], 9],
#  [['Ragi', 'Low'], 10],
#  [['Potato', 'Very_High'], 1],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Coriander', 'Very_Low'], 2],
#  [['Garlic', 'Very_High'], 4],
#  [['Wheat', 'High'], 4],
#  [['Sannhamp', 'Very_Low'], 9],
#  [['Cardamom', 'Very_Low'], 5],
#  [['Maize', 'Low'], 9],
#  [['Arhar/Tur', 'Low'], 10],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Cotton(lint)', 'Low'], 6],
#  [['Bajra', 'Very_Low'], 10],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Dry ginger', 'Very_High'], 5],
#  [['Cucumber', 'Very_Low'], 7],
#  [['Onion', 'Very_High'], 11],
#  [['Small millets', 'Very_Low'], 11],
#  [['Groundnut', 'Medium'], 0],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Jowar', 'Low'], 9],
#  [['Coconut ', 'Medium'], 1],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Urad', 'Very_Low'], 10],
#  [['Bajra', 'Low'], 10],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Urad', 'Very_Low'], 9],
#  [['Urad', 'Very_Low'], 9],
#  [['Jute', 'Very_High'], 9],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Sugarcane', 'Very_High'], 2],
#  [['Maize', 'Medium'], 0],
#  [['Sesamum', 'Very_Low'], 7],
#  [['Arhar/Tur', 'Very_Low'], 9],
#  [['Linseed', 'Low'], 4],
#  [['Maize', 'High'], 10],
#  [['Rice', 'High'], 1],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Small millets', 'Very_Low'], 9],
#  [['Arecanut', 'Low'], 1],
#  [['Cotton(lint)', 'Very_High'], 9],
#  [['Onion', 'Very_High'], 4],
#  [['Castor seed', 'Very_Low'], 11],
#  [['Garlic', 'Medium'], 6],
#  [['Potato', 'Very_High'], 7],
#  [['Groundnut', 'Medium'], 9],
#  [['Gram', 'Low'], 8],
#  [['Mango', 'Very_High'], 5],
#  [['Wheat', 'Medium'], 4],
#  [['Rice', 'High'], 10],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Rice', 'Low'], 10],
#  [['Gram', 'Low'], 4],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Barley', 'Medium'], 8],
#  [['Onion', 'Very_High'], 5],
#  [['Sannhamp', 'Very_Low'], 10],
#  [['Khesari', 'Low'], 4],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Mesta', 'Very_High'], 9],
#  [['Groundnut', 'Low'], 11],
#  [['Other Kharif pulses', 'Low'], 9],
#  [['Potato', 'Very_High'], 7],
#  [['Onion', 'Very_High'], 5],
#  [['Citrus Fruit', 'Very_Low'], 2],
#  [['Wheat', 'High'], 4],
#  [['Rice', 'Low'], 7],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Urad', 'Very_Low'], 8],
#  [['Coconut ', 'Very_High'], 5],
#  [['Small millets', 'Low'], 10],
#  [['Barley', 'Low'], 7],
#  [['Cotton(lint)', 'Medium'], 11],
#  [['Potato', 'Very_High'], 4],
#  [['Rice', 'High'], 10],
#  [['Maize', 'Very_High'], 10],
#  [['Maize', 'Low'], 0],
#  [['Arecanut', 'Very_Low'], 5],
#  [['Cotton(lint)', 'High'], 10],
#  [['Sunflower', 'Low'], 11],
#  [['Dry ginger', 'High'], 9],
#  [['Rice', 'Medium'], 10],
#  [['Potato', 'Very_High'], 4],
#  [['Jute', 'Very_High'], 9],
#  [['Groundnut', 'High'], 10],
#  [['Onion', 'Very_High'], 7],
#  [['Sannhamp', 'Very_High'], 9],
#  [['Cashewnut', 'Low'], 7],
#  [['Urad', 'Very_Low'], 7],
#  [['Maize', 'Low'], 9],
#  [['Sesamum', 'Very_Low'], 11],
#  [['Coriander', 'Very_Low'], 2],
#  [['Small millets', 'Low'], 9],
#  [['Turmeric', 'Very_High'], 5],
#  [['Gram', 'Low'], 2],
#  [['Rice', 'Medium'], 7],
#  [['Turmeric', 'Low'], 2],
#  [['Gram', 'Very_Low'], 4],
#  [['Potato', 'Very_High'], 1],
#  [['Niger seed', 'Low'], 9],
#  [['Small millets', 'Very_Low'], 11],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Wheat', 'Medium'], 3],
#  [['Sesamum', 'Low'], 2],
#  [['Arhar/Tur', 'Low'], 7],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Jute', 'Very_High'], 9],
#  [['Linseed', 'Low'], 2],
#  [['Other Kharif pulses', 'Very_Low'], 10],
#  [['Groundnut', 'Very_Low'], 11],
#  [['Tobacco', 'High'], 1],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Sesamum', 'Low'], 5],
#  [['Tobacco', 'Medium'], 6],
#  [['Arhar/Tur', 'Very_Low'], 10],
#  [['Rapeseed &Mustard', 'Very_Low'], 4],
#  [['Cauliflower', 'Very_Low'], 3],
#  [['Onion', 'Very_High'], 1],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Soyabean', 'Low'], 11],
#  [['Wheat', 'Low'], 7],
#  [['Other  Rabi pulses', 'Low'], 8],
#  [['Dry ginger', 'Low'], 9],
#  [['Maize', 'Very_High'], 0],
#  [['Potato', 'Very_High'], 1],
#  [['Coriander', 'Very_Low'], 5],
#  [['Maize', 'Low'], 10],
#  [['Dry chillies', 'Very_Low'], 6],
#  [['Ash Gourd', 'Very_Low'], 7],
#  [['Gram', 'Very_Low'], 4],
#  [['Sugarcane', 'Very_High'], 11],
#  [['Wheat', 'Very_High'], 4],
#  [['Other  Rabi pulses', 'Very_Low'], 7],
#  [['Potato', 'Very_High'], 1],
#  [['Dry chillies', 'Medium'], 3],
#  [['Sugarcane', 'Very_High'], 7],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Wheat', 'High'], 4],
#  [['Urad', 'Low'], 7],
#  [['Tapioca', 'Very_High'], 9],
#  [['Groundnut', 'Low'], 0],
#  [['Sunflower', 'Medium'], 7],
#  [['Sugarcane', 'Very_High'], 2],
#  [['Masoor', 'Low'], 4],
#  [['Other Kharif pulses', 'Very_Low'], 9],
#  [['Other Kharif pulses', 'Very_Low'], 11],
#  [['Potato', 'Very_High'], 1],
#  [['Gram', 'Very_Low'], 7],
#  [['Rapeseed &Mustard', 'Very_Low'], 8],
#  [['Potato', 'Very_High'], 1],
#  [['Jowar', 'Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 3],
#  [['Linseed', 'Very_Low'], 7],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Small millets', 'Very_Low'], 9],
#  [['Guar seed', 'Low'], 4],
#  [['Sannhamp', 'Very_Low'], 1],
#  [['Dry ginger', 'Medium'], 11],
#  [['Barley', 'Medium'], 4],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Wheat', 'Very_High'], 4],
#  [['Pome Fruit', 'High'], 7],
#  [['Small millets', 'Medium'], 9],
#  [['Rice', 'Medium'], 10],
#  [['Other Kharif pulses', 'Low'], 10],
#  [['Dry chillies', 'Low'], 5],
#  [['Safflower', 'Very_Low'], 7],
#  [['Sunflower', 'Low'], 9],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Groundnut', 'Medium'], 11],
#  [['Linseed', 'Very_Low'], 8],
#  [['Sunflower', 'Low'], 7],
#  [['Rapeseed &Mustard', 'Very_Low'], 4],
#  [['Coriander', 'Very_Low'], 4],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Gram', 'Low'], 4],
#  [['Moth', 'Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Arhar/Tur', 'Low'], 5],
#  [['Other Kharif pulses', 'Very_Low'], 11],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Maize', 'Low'], 7],
#  [['Rice', 'Low'], 7],
#  [['Rapeseed &Mustard', 'Low'], 8],
#  [['Rice', 'High'], 7],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Small millets', 'Low'], 9],
#  [['Maize', 'Low'], 11],
#  [['Dry chillies', 'Low'], 2],
#  [['Moong(Green Gram)', 'Very_Low'], 0],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Bajra', 'Low'], 9],
#  [['Gram', 'Low'], 4],
#  [['Peas & beans (Pulses)', 'Very_Low'], 2],
#  [['Barley', 'Low'], 4],
#  [['Barley', 'High'], 4],
#  [['Khesari', 'Very_Low'], 3],
#  [['Wheat', 'Very_High'], 4],
#  [['Small millets', 'Medium'], 10],
#  [['Turmeric', 'Very_High'], 6],
#  [['Sesamum', 'Very_Low'], 1],
#  [['Rapeseed &Mustard', 'Very_Low'], 8],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Other Cereals & Millets', 'Very_Low'], 11],
#  [['Pome Granet', 'Very_High'], 11],
#  [['Jowar', 'Low'], 9],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Other Kharif pulses', 'Low'], 10],
#  [['Rice', 'Very_High'], 8],
#  [['Dry ginger', 'Low'], 5],
#  [['Sesamum', 'Very_Low'], 7],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Rice', 'High'], 9],
#  [['Rice', 'Medium'], 2],
#  [['Rice', 'Medium'], 8],
#  [['Gram', 'Medium'], 7],
#  [['Linseed', 'Very_Low'], 8],
#  [['Linseed', 'Very_Low'], 4],
#  [['Arhar/Tur', 'Very_Low'], 10],
#  [['Tapioca', 'Very_High'], 5],
#  [['Bajra', 'Medium'], 9],
#  [['Dry ginger', 'Very_High'], 9],
#  [['Jowar', 'Very_Low'], 3],
#  [['Urad', 'Low'], 1],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Moth', 'Very_Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 10],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Gram', 'Low'], 5],
#  [['Dry chillies', 'Very_High'], 7],
#  [['Niger seed', 'Very_Low'], 11],
#  [['Rapeseed &Mustard', 'Low'], 8],
#  [['Arecanut', 'Medium'], 1],
#  [['Potato', 'Very_High'], 1],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 10],
#  [['Sweet potato', 'Very_High'], 3],
#  [['Sunflower', 'Very_Low'], 7],
#  [['Groundnut', 'Very_Low'], 10],
#  [['Coriander', 'Very_Low'], 1],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Sweet potato', 'Very_High'], 6],
#  [['Sunflower', 'Very_Low'], 3],
#  [['Urad', 'Very_Low'], 0],
#  [['Castor seed', 'Very_Low'], 7],
#  [['Dry ginger', 'Medium'], 2],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Ragi', 'Very_Low'], 7],
#  [['Maize', 'Medium'], 10],
#  [['Sunflower', 'Low'], 11],
#  [['Wheat', 'Low'], 7],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Pome Fruit', 'Very_High'], 7],
#  [['Wheat', 'Medium'], 4],
#  [['Niger seed', 'Very_Low'], 10],
#  [['Onion', 'Very_High'], 1],
#  [['Dry chillies', 'Very_Low'], 5],
#  [['Maize', 'Low'], 9],
#  [['Sunflower', 'Low'], 3],
#  [['Maize', 'Low'], 8],
#  [['Groundnut', 'Very_Low'], 10],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Wheat', 'High'], 4],
#  [['Jowar', 'Low'], 9],
#  [['Rice', 'Low'], 7],
#  [['Black pepper', 'Medium'], 8],
#  [['Peas & beans (Pulses)', 'Very_Low'], 3],
#  [['Jute', 'Medium'], 11],
#  [['Potato', 'High'], 10],
#  [['Soyabean', 'Low'], 11],
#  [['Other Fresh Fruits', 'Very_High'], 1],
#  [['Sunflower', 'Very_Low'], 7],
#  [['Arhar/Tur', 'Very_Low'], 5],
#  [['Garlic', 'Medium'], 3],
#  [['Small millets', 'Low'], 9],
#  [['Coriander', 'Low'], 5],
#  [['Sunflower', 'Medium'], 9],
#  [['Linseed', 'Very_Low'], 3],
#  [['Other  Rabi pulses', 'Very_Low'], 7],
#  [['Black pepper', 'Very_Low'], 7],
#  [['Sunflower', 'Very_Low'], 10],
#  [['Coconut ', 'Very_High'], 5],
#  [['Turmeric', 'Very_Low'], 2],
#  [['Sugarcane', 'Very_High'], 9],
#  [['Wheat', 'Medium'], 8],
#  [['Bajra', 'Very_Low'], 9],
#  [['Onion', 'High'], 4],
#  [['Sugarcane', 'Very_High'], 4],
#  [['Masoor', 'Very_Low'], 8],
#  [['Rice', 'Low'], 1],
#  [['Potato', 'Very_High'], 1],
#  [['Garlic', 'Medium'], 5],
#  [['Gram', 'Low'], 7],
#  [['Bajra', 'Low'], 9],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Arhar/Tur', 'Medium'], 9],
#  [['Jowar', 'Low'], 9],
#  [['Cotton(lint)', 'Low'], 6],
#  [['Potato', 'Very_High'], 4],
#  [['Wheat', 'Very_High'], 4],
#  [['Onion', 'Low'], 1],
#  [['Potato', 'Very_High'], 2],
#  [['Rice', 'Medium'], 7],
#  [['Urad', 'Low'], 7],
#  [['Bajra', 'Very_Low'], 10],
#  [['Coconut ', 'Very_High'], 7],
#  [['Onion', 'Very_High'], 10],
#  [['Rice', 'Very_High'], 11],
#  [['Rapeseed &Mustard', 'Very_Low'], 2],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Maize', 'Medium'], 10],
#  [['Sunflower', 'Low'], 11],
#  [['Sesamum', 'Very_Low'], 11],
#  [['Potato', 'Very_High'], 4],
#  [['Groundnut', 'Medium'], 11],
#  [['Wheat', 'Very_High'], 4],
#  [['Coconut ', 'Very_High'], 5],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Moong(Green Gram)', 'Low'], 10],
#  [['Maize', 'Low'], 4],
#  [['Sesamum', 'Very_Low'], 3],
#  [['Bajra', 'Very_Low'], 2],
#  [['Coriander', 'Very_Low'], 5],
#  [['Mesta', 'Very_High'], 9],
#  [['Turmeric', 'Low'], 1],
#  [['Horse-gram', 'Very_Low'], 0],
#  [['Groundnut', 'Low'], 10],
#  [['Maize', 'Very_High'], 3],
#  [['Turmeric', 'Low'], 3],
#  [['Banana', 'Very_High'], 6],
#  [['Groundnut', 'Low'], 10],
#  [['Sannhamp', 'Very_High'], 9],
#  [['Rice', 'Very_Low'], 7],
#  [['Sunflower', 'Medium'], 8],
#  [['Onion', 'Very_High'], 4],
#  [['Rice', 'Low'], 10],
#  [['Maize', 'High'], 1],
#  [['Linseed', 'Very_Low'], 4],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Jowar', 'Low'], 10],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Moth', 'Very_Low'], 9],
#  [['Onion', 'Very_High'], 10],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Maize', 'Very_Low'], 9],
#  [['Urad', 'Very_Low'], 0],
#  [['Moong(Green Gram)', 'Very_Low'], 1],
#  [['Ragi', 'Very_High'], 7],
#  [['Gram', 'Low'], 7],
#  [['Coconut ', 'Very_High'], 1],
#  [['Onion', 'Very_High'], 7],
#  [['Khesari', 'Very_Low'], 4],
#  [['Sesamum', 'Low'], 10],
#  [['Urad', 'Very_Low'], 11],
#  [['Turmeric', 'Very_High'], 7],
#  [['Pome Fruit', 'Very_Low'], 4],
#  [['Arhar/Tur', 'Low'], 10],
#  [['Groundnut', 'Low'], 9],
#  [['Masoor', 'Very_Low'], 8],
#  [['Other  Rabi pulses', 'Very_Low'], 3],
#  [['Wheat', 'Very_High'], 4],
#  [['Soyabean', 'Low'], 11],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Other Vegetables', 'Very_High'], 5],
#  [['Khesari', 'Low'], 4],
#  [['Other  Rabi pulses', 'Low'], 4],
#  [['Other Kharif pulses', 'Low'], 9],
#  [['Groundnut', 'Low'], 7],
#  [['Gram', 'Low'], 3],
#  [['Tobacco', 'Low'], 1],
#  [['Dry chillies', 'Low'], 1],
#  [['Tapioca', 'Very_High'], 7],
#  [['Rice', 'Very_High'], 7],
#  [['Small millets', 'Low'], 11],
#  [['Rapeseed &Mustard', 'Very_Low'], 7],
#  [['Maize', 'Very_High'], 10],
#  [['Castor seed', 'Very_Low'], 10],
#  [['Potato', 'Very_High'], 7],
#  [['Barley', 'High'], 4],
#  [['Small millets', 'Low'], 9],
#  [['Rapeseed &Mustard', 'Medium'], 8],
#  [['Coriander', 'Low'], 1],
#  [['Bajra', 'Low'], 9],
#  [['Jowar', 'Low'], 9],
#  [['Potato', 'Very_High'], 8],
#  [['Maize', 'Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Bajra', 'Low'], 10],
#  [['Maize', 'High'], 9],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Cashewnut', 'Low'], 5],
#  [['Turmeric', 'High'], 1],
#  [['Potato', 'Very_High'], 4],
#  [['Dry chillies', 'Very_Low'], 5],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Niger seed', 'Low'], 9],
#  [['Onion', 'Very_High'], 5],
#  [['Soyabean', 'Very_Low'], 9],
#  [['Arhar/Tur', 'Medium'], 5],
#  [['Cowpea(Lobia)', 'Medium'], 6],
#  [['Masoor', 'Very_Low'], 4],
#  [['Peas & beans (Pulses)', 'Low'], 4],
#  [['Dry chillies', 'Low'], 11],
#  [['Ragi', 'Medium'], 10],
#  [['Maize', 'Very_High'], 7],
#  [['Tomato', 'Very_High'], 5],
#  [['Masoor', 'Very_Low'], 6],
#  [['Groundnut', 'Very_Low'], 9],
#  [['Sesamum', 'Low'], 9],
#  [['Groundnut', 'Low'], 10],
#  [['Linseed', 'Low'], 4],
#  [['Maize', 'Medium'], 9],
#  [['Rice', 'High'], 11],
#  [['Rice', 'Very_Low'], 11],
#  [['Mesta', 'Very_High'], 9],
#  [['Urad', 'Very_Low'], 9],
#  [['Small millets', 'Very_Low'], 11],
#  [['Maize', 'Very_High'], 4],
#  [['Jute', 'Very_High'], 9],
#  [['Urad', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Very_Low'], 7],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Gram', 'Low'], 4],
#  [['Dry chillies', 'Medium'], 7],
#  [['Rice', 'High'], 7],
#  [['Barley', 'High'], 4],
#  [['Linseed', 'Very_Low'], 4],
#  [['Ragi', 'High'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Arhar/Tur', 'Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Coriander', 'Very_Low'], 7],
#  [['Sesamum', 'Very_Low'], 7],
#  [['Coconut ', 'Very_High'], 7],
#  [['Small millets', 'Very_Low'], 10],
#  [['Turmeric', 'Medium'], 1],
#  [['Wheat', 'Very_High'], 8],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Rapeseed &Mustard', 'Very_Low'], 8],
#  [['Moong(Green Gram)', 'Very_Low'], 10],
#  [['Tapioca', 'Very_High'], 5],
#  [['Wheat', 'High'], 4],
#  [['Barley', 'Very_High'], 4],
#  [['Pump Kin', 'Very_Low'], 7],
#  [['Rapeseed &Mustard', 'Low'], 8],
#  [['Maize', 'Very_High'], 9],
#  [['Cotton(lint)', 'Very_Low'], 10],
#  [['Maize', 'Very_High'], 5],
#  [['Sweet potato', 'Very_High'], 9],
#  [['Urad', 'Very_Low'], 3],
#  [['Brinjal', 'Very_High'], 11],
#  [['Maize', 'High'], 4],
#  [['Guar seed', 'Very_Low'], 6],
#  [['Dry chillies', 'Very_Low'], 1],
#  [['Rice', 'Very_High'], 7],
#  [['Garlic', 'High'], 4],
#  [['Rice', 'Very_Low'], 4],
#  [['Gram', 'Very_Low'], 10],
#  [['Rice', 'High'], 2],
#  [['Tobacco', 'Low'], 4],
#  [['Rice', 'High'], 4],
#  [['Other Kharif pulses', 'Low'], 10],
#  [['Total foodgrain', 'Medium'], 5],
#  [['Potato', 'Very_High'], 4],
#  [['Sweet potato', 'Very_High'], 9],
#  [['Rice', 'High'], 10],
#  [['Tomato', 'Very_High'], 7],
#  [['Sannhamp', 'Very_Low'], 10],
#  [['Turmeric', 'Very_Low'], 1],
#  [['Colocosia', 'Very_High'], 11],
#  [['Turmeric', 'Very_High'], 4],
#  [['Urad', 'Low'], 9],
#  [['Castor seed', 'Very_Low'], 9],
#  [['Gram', 'Very_Low'], 3],
#  [['Pulses total', 'Very_Low'], 1],
#  [['Arecanut', 'Low'], 6],
#  [['Masoor', 'Very_Low'], 7],
#  [['Jowar', 'Very_Low'], 11],
#  [['Niger seed', 'Very_Low'], 10],
#  [['Groundnut', 'Low'], 9],
#  [['Rice', 'Very_High'], 10],
#  [['Gram', 'Very_Low'], 3],
#  [['Sunflower', 'Medium'], 5],
#  [['Sannhamp', 'Very_High'], 9],
#  [['Dry chillies', 'Very_High'], 10],
#  [['Black pepper', 'Very_High'], 5],
#  [['Pulses total', 'Very_Low'], 2],
#  [['Dry chillies', 'Low'], 5],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Niger seed', 'Very_Low'], 9],
#  [['Castor seed', 'Very_Low'], 10],
#  [['Barley', 'Medium'], 4],
#  [['Rice', 'High'], 10],
#  [['Safflower', 'Very_Low'], 7],
#  [['Barley', 'Low'], 4],
#  [['Rice', 'Low'], 9],
#  [['Castor seed', 'Very_Low'], 11],
#  [['Maize', 'Very_High'], 7],
#  [['Urad', 'Very_Low'], 10],
#  [['Other Kharif pulses', 'Very_Low'], 10],
#  [['Moong(Green Gram)', 'Low'], 4],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Wheat', 'High'], 3],
#  [['Arhar/Tur', 'Low'], 11],
#  [['Peas & beans (Pulses)', 'Low'], 4],
#  [['Arhar/Tur', 'Very_Low'], 11],
#  [['Bajra', 'Very_Low'], 7],
#  [['Dry chillies', 'Low'], 1],
#  [['Maize', 'Medium'], 9],
#  [['Moth', 'Low'], 9],
#  [['Wheat', 'High'], 4],
#  [['Rice', 'Very_Low'], 10],
#  [['Other  Rabi pulses', 'Low'], 4],
#  [['Rice', 'Very_High'], 11],
#  [['Tobacco', 'Medium'], 5],
#  [['Maize', 'Medium'], 9],
#  [['Wheat', 'Very_High'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 8],
#  [['Rice', 'Medium'], 4],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Banana', 'Very_High'], 1],
#  [['Rice', 'Very_High'], 1],
#  [['Maize', 'Very_High'], 4],
#  [['Barley', 'High'], 3],
#  [['Dry chillies', 'Very_Low'], 10],
#  [['Rice', 'Very_High'], 11],
#  [['Urad', 'Low'], 9],
#  [['Guar seed', 'Low'], 9],
#  [['Masoor', 'Low'], 4],
#  [['Orange', 'Very_High'], 1],
#  [['Groundnut', 'Medium'], 7],
#  [['Urad', 'Very_Low'], 9],
#  [['Dry chillies', 'Very_Low'], 1],
#  [['Cowpea(Lobia)', 'Very_Low'], 3],
#  [['Maize', 'Very_High'], 11],
#  [['Maize', 'Very_High'], 4],
#  [['Rice', 'Low'], 9],
#  [['Maize', 'Medium'], 4],
#  [['Maize', 'High'], 1],
#  [['Horse-gram', 'Very_Low'], 4],
#  [['Other Fresh Fruits', 'Very_Low'], 2],
#  [['Gram', 'Low'], 7],
#  [['Orange', 'High'], 7],
#  [['Wheat', 'Low'], 8],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Moth', 'Very_Low'], 9],
#  [['Sweet potato', 'Very_High'], 2],
#  [['Small millets', 'Medium'], 5],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Jute', 'Very_High'], 9],
#  [['Sweet potato', 'Low'], 4],
#  [['Dry chillies', 'Very_Low'], 3],
#  [['Barley', 'High'], 3],
#  [['Rice', 'Medium'], 0],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Sunflower', 'Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Soyabean', 'Low'], 10],
#  [['Bajra', 'Very_Low'], 10],
#  [['Cotton(lint)', 'Very_Low'], 10],
#  [['Maize', 'Medium'], 0],
#  [['Masoor', 'Low'], 4],
#  [['Wheat', 'Medium'], 8],
#  [['Masoor', 'Low'], 4],
#  [['Turmeric', 'High'], 1],
#  [['Other Kharif pulses', 'Very_Low'], 11],
#  [['Sunflower', 'Very_Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Sweet potato', 'Very_High'], 8],
#  [['Turmeric', 'Medium'], 3],
#  [['Maize', 'High'], 7],
#  [['Tomato', 'Very_High'], 7],
#  [['Gram', 'Very_Low'], 7],
#  [['Rapeseed &Mustard', 'Very_Low'], 7],
#  [['Onion', 'Very_High'], 7],
#  [['Oilseeds total', 'Medium'], 5],
#  [['Barley', 'Low'], 8],
#  [['Moong(Green Gram)', 'Low'], 1],
#  [['Bajra', 'Low'], 10],
#  [['Peas & beans (Pulses)', 'Medium'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Coriander', 'Very_Low'], 5],
#  [['Sugarcane', 'Very_High'], 2],
#  [['Wheat', 'Very_High'], 4],
#  [['Gram', 'Very_Low'], 7],
#  [['Banana', 'Very_High'], 5],
#  [['Dry ginger', 'Very_High'], 6],
#  [['Groundnut', 'High'], 7],
#  [['Rice', 'Medium'], 8],
#  [['Moong(Green Gram)', 'Low'], 1],
#  [['Black pepper', 'Low'], 5],
#  [['Gram', 'Low'], 4],
#  [['Sugarcane', 'Very_High'], 4],
#  [['Wheat', 'Medium'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 1],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Banana', 'Very_High'], 1],
#  [['Water Melon', 'Very_Low'], 2],
#  [['Potato', 'Very_High'], 1],
#  [['Bajra', 'Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Other Kharif pulses', 'Very_Low'], 10],
#  [['Moth', 'Very_Low'], 9],
#  [['Sugarcane', 'Very_High'], 2],
#  [['Safflower', 'Low'], 7],
#  [['Tapioca', 'Very_High'], 1],
#  [['Horse-gram', 'Very_Low'], 7],
#  [['Rapeseed &Mustard', 'Medium'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Coriander', 'Very_Low'], 7],
#  [['Potato', 'Very_High'], 7],
#  [['Rice', 'Low'], 4],
#  [['Rice', 'High'], 6],
#  [['Groundnut', 'Very_Low'], 11],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Rice', 'Very_High'], 11],
#  [['Tobacco', 'High'], 1],
#  [['Masoor', 'Low'], 4],
#  [['Maize', 'High'], 11],
#  [['Rice', 'Very_High'], 9],
#  [['Barley', 'Very_High'], 8],
#  [['Mesta', 'Very_High'], 9],
#  ...]

# %%
df
# Out:
#                          Crop Yield_Disc
# 0                   Cashewnut        Low
# 1                       Maize        Low
# 2                Cotton(lint)   Very_Low
# 3                     Sesamum   Very_Low
# 4                        Urad   Very_Low
# ...                       ...        ...
# 169650           Cotton(lint)   Very_Low
# 169651                Linseed   Very_Low
# 169652      Moong(Green Gram)   Very_Low
# 169653                  Onion       High
# 169654  Peas & beans (Pulses)   Very_Low
#
# [169655 rows x 2 columns]

# %%
DF
# Out:
#             Season                   Crop Soil Type Rainfall_Disc Yield_Disc
# 0       Whole Year              Cashewnut       Red        Medium        Low
# 1           Summer                  Maize       Red           Low        Low
# 2           Kharif           Cotton(lint)       Red        Medium   Very_Low
# 3           Kharif                Sesamum  Alluvial          High   Very_Low
# 4             Rabi                   Urad       Red           Low   Very_Low
# ...            ...                    ...       ...           ...        ...
# 169650      Kharif           Cotton(lint)     Black          High   Very_Low
# 169651        Rabi                Linseed  Alluvial           Low   Very_Low
# 169652      Summer      Moong(Green Gram)  Alluvial          High   Very_Low
# 169653  Whole Year                  Onion  Alluvial           Low       High
# 169654  Whole Year  Peas & beans (Pulses)     Black        Medium   Very_Low
#
# [169655 rows x 5 columns]

# %%
DF = DF[['Season', 'Crop', 'Soil Type', 'Rainfall_Disc']]

# %%
DF
# Out:
#             Season                   Crop Soil Type Rainfall_Disc
# 0       Whole Year              Cashewnut       Red        Medium
# 1           Summer                  Maize       Red           Low
# 2           Kharif           Cotton(lint)       Red        Medium
# 3           Kharif                Sesamum  Alluvial          High
# 4             Rabi                   Urad       Red           Low
# ...            ...                    ...       ...           ...
# 169650      Kharif           Cotton(lint)     Black          High
# 169651        Rabi                Linseed  Alluvial           Low
# 169652      Summer      Moong(Green Gram)  Alluvial          High
# 169653  Whole Year                  Onion  Alluvial           Low
# 169654  Whole Year  Peas & beans (Pulses)     Black        Medium
#
# [169655 rows x 4 columns]

# %%
xs = list(set(list(DF['Season'])))
ys = list(set(list(DF['Soil Type'])))
zs = list(set(list(DF.Rainfall_Disc)))

crop_dict = dict()
Crops = list((DF['Crop']))
for i, crop in enumerate(Crops):
    if crop not in crop_dict.keys():
        crop_dict[crop] = []
    
    season = DF.at(i)
    soil_type = DF[i+1]['Soil Type']
    rainfall = DF[i+1]['Rainfall_Disc']
    
    crop_dict[crop] = [season, soil_type, rainfall]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/DM/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-3743bf4a32cf> in <module>
#       9         crop_dict[crop] = []
#      10
# ---> 11     season = DF[i+1]['Season']
#      12     soil_type = DF[i+1]['Soil Type']
#      13     rainfall = DF[i+1]['Rainfall_Disc']
#
# ~/DM/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/DM/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
# Piechart

ans
# Out:
# [[['Cashewnut', 'Low'], 5],
#  [['Maize', 'Low'], 0],
#  [['Cotton(lint)', 'Very_Low'], 11],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Urad', 'Very_Low'], 7],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Linseed', 'Very_Low'], 11],
#  [['Sunflower', 'Very_Low'], 11],
#  [['Wheat', 'Medium'], 4],
#  [['Coconut ', 'Very_High'], 5],
#  [['Ginger', 'Very_High'], 9],
#  [['Tobacco', 'Very_Low'], 3],
#  [['Urad', 'Very_Low'], 11],
#  [['Other  Rabi pulses', 'Low'], 4],
#  [['Dry chillies', 'Very_High'], 5],
#  [['Maize', 'Very_High'], 11],
#  [['Wheat', 'Low'], 8],
#  [['Urad', 'Very_Low'], 7],
#  [['Rice', 'Medium'], 7],
#  [['Groundnut', 'Low'], 2],
#  [['Bajra', 'Medium'], 9],
#  [['Grapes', 'Very_High'], 2],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Mesta', 'Very_High'], 11],
#  [['Gram', 'Low'], 4],
#  [['Urad', 'Very_Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 10],
#  [['Sunflower', 'Very_Low'], 10],
#  [['Onion', 'Very_High'], 2],
#  [['Black pepper', 'Very_Low'], 5],
#  [['Sunflower', 'Very_Low'], 0],
#  [['Potato', 'Very_High'], 2],
#  [['Sesamum', 'Very_Low'], 0],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Groundnut', 'Low'], 7],
#  [['Ragi', 'Low'], 10],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Turmeric', 'Medium'], 5],
#  [['Black pepper', 'Medium'], 1],
#  [['Moong(Green Gram)', 'Low'], 1],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Medium'], 4],
#  [['Ragi', 'Medium'], 7],
#  [['Wheat', 'Low'], 8],
#  [['Peas & beans (Pulses)', 'Medium'], 4],
#  [['Tapioca', 'Very_High'], 5],
#  [['Soyabean', 'Low'], 10],
#  [['Urad', 'Low'], 3],
#  [['Bajra', 'Low'], 9],
#  [['Maize', 'Very_High'], 10],
#  [['Dry chillies', 'Very_Low'], 10],
#  [['Arecanut', 'Low'], 5],
#  [['Niger seed', 'Very_Low'], 10],
#  [['Rice', 'Very_High'], 0],
#  [['Potato', 'Very_High'], 7],
#  [['Gram', 'Low'], 4],
#  [['Mesta', 'Very_High'], 9],
#  [['Groundnut', 'Medium'], 10],
#  [['Sunflower', 'Low'], 10],
#  [['Groundnut', 'Low'], 9],
#  [['Rice', 'Very_High'], 11],
#  [['Linseed', 'Low'], 4],
#  [['Potato', 'Very_High'], 2],
#  [['Cotton(lint)', 'Low'], 2],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Barley', 'Medium'], 3],
#  [['Rice', 'Low'], 7],
#  [['Onion', 'High'], 4],
#  [['Maize', 'High'], 11],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Arhar/Tur', 'Very_Low'], 9],
#  [['Rice', 'Very_High'], 11],
#  [['Arhar/Tur', 'Very_Low'], 6],
#  [['Tobacco', 'Very_High'], 7],
#  [['Coriander', 'Very_Low'], 1],
#  [['Rice', 'Medium'], 0],
#  [['Sugarcane', 'Very_High'], 9],
#  [['Guar seed', 'Low'], 9],
#  [['Moong(Green Gram)', 'Low'], 11],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Sesamum', 'Very_Low'], 11],
#  [['Potato', 'Very_High'], 5],
#  [['Sunflower', 'Medium'], 4],
#  [['Turmeric', 'Medium'], 2],
#  [['Tobacco', 'Very_High'], 4],
#  [['Dry chillies', 'Low'], 4],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Coconut ', 'Very_High'], 1],
#  [['Khesari', 'Very_Low'], 4],
#  [['Arhar/Tur', 'Low'], 10],
#  [['Arhar/Tur', 'Medium'], 2],
#  [['Sesamum', 'Very_Low'], 0],
#  [['Black pepper', 'High'], 7],
#  [['Rice', 'High'], 9],
#  [['Maize', 'High'], 9],
#  [['Maize', 'High'], 3],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Potato', 'Medium'], 4],
#  [['Groundnut', 'Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Sweet potato', 'Low'], 4],
#  [['Sunflower', 'Low'], 11],
#  [['Turmeric', 'Very_High'], 7],
#  [['Soyabean', 'Very_Low'], 10],
#  [['Onion', 'Very_High'], 1],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Ragi', 'Very_Low'], 7],
#  [['Small millets', 'Low'], 11],
#  [['Barley', 'Very_High'], 8],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Castor seed', 'Very_Low'], 9],
#  [['Urad', 'Very_Low'], 1],
#  [['Dry chillies', 'Very_High'], 7],
#  [['Groundnut', 'Very_Low'], 10],
#  [['Groundnut', 'Low'], 7],
#  [['Sesamum', 'Low'], 10],
#  [['Tapioca', 'Very_High'], 11],
#  [['Maize', 'Medium'], 4],
#  [['Maize', 'Medium'], 10],
#  [['Jowar', 'Low'], 10],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Rapeseed &Mustard', 'Medium'], 4],
#  [['Groundnut', 'Low'], 7],
#  [['Sesamum', 'Very_Low'], 0],
#  [['Onion', 'Very_High'], 5],
#  [['Garlic', 'Medium'], 1],
#  [['Cotton(lint)', 'Low'], 10],
#  [['Urad', 'Very_Low'], 9],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Snak Guard', 'Very_Low'], 7],
#  [['Coriander', 'Very_Low'], 4],
#  [['Banana', 'Very_High'], 5],
#  [['Castor seed', 'Very_Low'], 9],
#  [['Maize', 'Low'], 7],
#  [['Small millets', 'Low'], 9],
#  [['Garlic', 'Very_High'], 4],
#  [['Barley', 'High'], 4],
#  [['Masoor', 'Low'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Maize', 'Low'], 7],
#  [['Garlic', 'Very_High'], 4],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Other  Rabi pulses', 'Very_Low'], 7],
#  [['Coriander', 'Very_Low'], 5],
#  [['Rice', 'Low'], 7],
#  [['Niger seed', 'Very_Low'], 2],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Ragi', 'Medium'], 11],
#  [['Banana', 'Very_High'], 7],
#  [['Onion', 'Very_High'], 4],
#  [['Arecanut', 'Low'], 5],
#  [['Arecanut', 'Low'], 5],
#  [['Guar seed', 'Very_Low'], 4],
#  [['Maize', 'Medium'], 9],
#  [['Groundnut', 'Low'], 10],
#  [['Jowar', 'Very_Low'], 7],
#  [['Potato', 'Very_High'], 7],
#  [['Dry chillies', 'Very_High'], 1],
#  [['Barley', 'Low'], 8],
#  [['Masoor', 'Medium'], 8],
#  [['Sunflower', 'Low'], 4],
#  [['Dry ginger', 'Medium'], 11],
#  [['Rice', 'High'], 1],
#  [['Barley', 'High'], 4],
#  [['Other Kharif pulses', 'Very_Low'], 10],
#  [['Bajra', 'Medium'], 10],
#  [['Cotton(lint)', 'Medium'], 6],
#  [['Rice', 'High'], 9],
#  [['Jowar', 'Very_High'], 11],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Rice', 'Medium'], 1],
#  [['Arhar/Tur', 'Very_Low'], 9],
#  [['Peas & beans (Pulses)', 'Very_Low'], 7],
#  [['Wheat', 'Medium'], 7],
#  [['Onion', 'Very_High'], 5],
#  [['Jowar', 'Very_Low'], 11],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Jute', 'Very_High'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Snak Guard', 'Very_Low'], 5],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Sunflower', 'Low'], 3],
#  [['Masoor', 'Very_Low'], 3],
#  [['Banana', 'Very_High'], 3],
#  [['Wheat', 'High'], 3],
#  [['Sunflower', 'Very_Low'], 8],
#  [['Snak Guard', 'Very_Low'], 5],
#  [['Bajra', 'Low'], 9],
#  [['Peas & beans (Pulses)', 'Medium'], 4],
#  [['Sunflower', 'Very_Low'], 10],
#  [['Groundnut', 'Low'], 11],
#  [['Tobacco', 'Very_High'], 4],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Maize', 'High'], 1],
#  [['Jute', 'Very_High'], 9],
#  [['Arecanut', 'Very_High'], 5],
#  [['Dry ginger', 'Medium'], 9],
#  [['Masoor', 'Very_Low'], 2],
#  [['Rapeseed &Mustard', 'Low'], 8],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Rice', 'High'], 9],
#  [['Soyabean', 'Low'], 10],
#  [['Sunflower', 'Very_Low'], 10],
#  [['Sunflower', 'Medium'], 9],
#  [['Dry ginger', 'Very_Low'], 10],
#  [['Gram', 'Low'], 4],
#  [['Barley', 'High'], 4],
#  [['Tapioca', 'Very_High'], 1],
#  [['Groundnut', 'Medium'], 0],
#  [['Onion', 'Very_High'], 11],
#  [['Gram', 'Low'], 4],
#  [['Arhar/Tur', 'Very_Low'], 10],
#  [['Dry ginger', 'Very_High'], 11],
#  [['Masoor', 'Very_Low'], 8],
#  [['Horse-gram', 'Very_Low'], 10],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Onion', 'Very_High'], 2],
#  [['Rice', 'Very_High'], 7],
#  [['Rice', 'Low'], 10],
#  [['Urad', 'Low'], 1],
#  [['Maize', 'Very_High'], 11],
#  [['Coconut ', 'Very_High'], 1],
#  [['Masoor', 'Very_Low'], 7],
#  [['Banana', 'Very_High'], 1],
#  [['Dry chillies', 'Medium'], 7],
#  [['Urad', 'Very_Low'], 1],
#  [['Niger seed', 'Very_Low'], 10],
#  [['Wheat', 'Very_High'], 3],
#  [['Peas & beans (Pulses)', 'High'], 4],
#  [['Arhar/Tur', 'Very_Low'], 2],
#  [['Rapeseed &Mustard', 'High'], 4],
#  [['Cardamom', 'Very_Low'], 5],
#  [['Rice', 'Medium'], 9],
#  [['Tapioca', 'Very_High'], 1],
#  [['Urad', 'Low'], 9],
#  [['Maize', 'Very_High'], 1],
#  [['Other Kharif pulses', 'Very_Low'], 11],
#  [['Urad', 'Low'], 11],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Cotton(lint)', 'Low'], 11],
#  [['Snak Guard', 'Very_Low'], 5],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Rice', 'Very_High'], 11],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Maize', 'High'], 7],
#  [['Barley', 'Very_High'], 4],
#  [['Garlic', 'Very_High'], 5],
#  [['Peas & beans (Pulses)', 'Low'], 8],
#  [['Dry chillies', 'Low'], 5],
#  [['Cotton(lint)', 'High'], 11],
#  [['Banana', 'Very_High'], 5],
#  [['Jute', 'Very_High'], 9],
#  [['Other Cereals & Millets', 'Low'], 8],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Onion', 'Very_High'], 2],
#  [['Tobacco', 'Very_High'], 4],
#  [['Linseed', 'Very_Low'], 8],
#  [['Bajra', 'Medium'], 9],
#  [['Mesta', 'Very_High'], 9],
#  [['Gram', 'Low'], 4],
#  [['Rice', 'High'], 9],
#  [['Rice', 'High'], 0],
#  [['Bajra', 'Low'], 9],
#  [['Peas & beans (Pulses)', 'Low'], 4],
#  [['Other Kharif pulses', 'Low'], 9],
#  [['Bajra', 'Low'], 9],
#  [['Other Vegetables', 'Very_Low'], 7],
#  [['Groundnut', 'Very_High'], 11],
#  [['Bajra', 'Low'], 10],
#  [['Sesamum', 'Low'], 10],
#  [['Urad', 'Very_Low'], 9],
#  [['Rice', 'High'], 0],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Maize', 'Medium'], 3],
#  [['Banana', 'Very_High'], 5],
#  [['Other Fresh Fruits', 'High'], 5],
#  [['Small millets', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Very_Low'], 7],
#  [['Groundnut', 'Very_Low'], 11],
#  [['Dry chillies', 'High'], 11],
#  [['Peas & beans (Pulses)', 'Medium'], 4],
#  [['Maize', 'Very_High'], 11],
#  [['Cotton(lint)', 'Low'], 10],
#  [['Potato', 'Very_High'], 4],
#  [['Banana', 'Very_High'], 5],
#  [['Banana', 'Very_High'], 6],
#  [['Maize', 'Very_High'], 10],
#  [['Ragi', 'Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Arhar/Tur', 'Low'], 10],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Maize', 'Very_Low'], 11],
#  [['Rapeseed &Mustard', 'Very_Low'], 4],
#  [['Turmeric', 'Very_High'], 5],
#  [['Ragi', 'Very_Low'], 7],
#  [['Masoor', 'Very_Low'], 4],
#  [['Masoor', 'Very_Low'], 8],
#  [['Jute', 'Medium'], 10],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Other Kharif pulses', 'Very_Low'], 9],
#  [['Banana', 'Very_High'], 5],
#  [['Bajra', 'Medium'], 9],
#  [['Gram', 'Low'], 8],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Dry chillies', 'Low'], 9],
#  [['Mesta', 'Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Rice', 'Low'], 10],
#  [['Coriander', 'Very_Low'], 5],
#  [['Urad', 'Very_Low'], 3],
#  [['Dry chillies', 'Very_Low'], 1],
#  [['Jowar', 'Very_High'], 7],
#  [['Linseed', 'Very_Low'], 8],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Masoor', 'Low'], 4],
#  [['Maize', 'Low'], 7],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Sunflower', 'Low'], 9],
#  [['Bajra', 'Low'], 7],
#  [['Rice', 'Very_Low'], 7],
#  [['Rice', 'High'], 1],
#  [['Dry ginger', 'Very_High'], 9],
#  [['Castor seed', 'Very_Low'], 10],
#  [['Wheat', 'Low'], 8],
#  [['Paddy', 'Very_High'], 0],
#  [['Coriander', 'Low'], 5],
#  [['Dry chillies', 'Low'], 9],
#  [['Maize', 'Very_High'], 7],
#  [['Groundnut', 'Medium'], 0],
#  [['Gram', 'Medium'], 4],
#  [['Jowar', 'Low'], 9],
#  [['Arecanut', 'Medium'], 8],
#  [['Rapeseed &Mustard', 'Very_Low'], 8],
#  [['Ragi', 'Very_High'], 11],
#  [['Bajra', 'Very_Low'], 6],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Bajra', 'Low'], 10],
#  [['Small millets', 'Low'], 11],
#  [['Small millets', 'Very_Low'], 10],
#  [['Dry chillies', 'Medium'], 7],
#  [['Black pepper', 'Low'], 5],
#  [['Groundnut', 'Low'], 9],
#  [['other oilseeds', 'Very_Low'], 10],
#  [['Other  Rabi pulses', 'Low'], 7],
#  [['Sunflower', 'Very_Low'], 0],
#  [['Potato', 'Very_High'], 1],
#  [['Rice', 'Low'], 9],
#  [['Masoor', 'Very_Low'], 4],
#  [['Niger seed', 'Very_Low'], 9],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Mesta', 'Very_Low'], 2],
#  [['Barley', 'Low'], 7],
#  [['Other Kharif pulses', 'Low'], 10],
#  [['Barley', 'Very_High'], 4],
#  [['Small millets', 'Very_Low'], 10],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Barley', 'High'], 4],
#  [['Castor seed', 'Very_Low'], 9],
#  [['Ragi', 'Low'], 10],
#  [['Potato', 'Very_High'], 1],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Coriander', 'Very_Low'], 2],
#  [['Garlic', 'Very_High'], 4],
#  [['Wheat', 'High'], 4],
#  [['Sannhamp', 'Very_Low'], 9],
#  [['Cardamom', 'Very_Low'], 5],
#  [['Maize', 'Low'], 9],
#  [['Arhar/Tur', 'Low'], 10],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Cotton(lint)', 'Low'], 6],
#  [['Bajra', 'Very_Low'], 10],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Dry ginger', 'Very_High'], 5],
#  [['Cucumber', 'Very_Low'], 7],
#  [['Onion', 'Very_High'], 11],
#  [['Small millets', 'Very_Low'], 11],
#  [['Groundnut', 'Medium'], 0],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Jowar', 'Low'], 9],
#  [['Coconut ', 'Medium'], 1],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Urad', 'Very_Low'], 10],
#  [['Bajra', 'Low'], 10],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Urad', 'Very_Low'], 9],
#  [['Urad', 'Very_Low'], 9],
#  [['Jute', 'Very_High'], 9],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Sugarcane', 'Very_High'], 2],
#  [['Maize', 'Medium'], 0],
#  [['Sesamum', 'Very_Low'], 7],
#  [['Arhar/Tur', 'Very_Low'], 9],
#  [['Linseed', 'Low'], 4],
#  [['Maize', 'High'], 10],
#  [['Rice', 'High'], 1],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Small millets', 'Very_Low'], 9],
#  [['Arecanut', 'Low'], 1],
#  [['Cotton(lint)', 'Very_High'], 9],
#  [['Onion', 'Very_High'], 4],
#  [['Castor seed', 'Very_Low'], 11],
#  [['Garlic', 'Medium'], 6],
#  [['Potato', 'Very_High'], 7],
#  [['Groundnut', 'Medium'], 9],
#  [['Gram', 'Low'], 8],
#  [['Mango', 'Very_High'], 5],
#  [['Wheat', 'Medium'], 4],
#  [['Rice', 'High'], 10],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Rice', 'Low'], 10],
#  [['Gram', 'Low'], 4],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Barley', 'Medium'], 8],
#  [['Onion', 'Very_High'], 5],
#  [['Sannhamp', 'Very_Low'], 10],
#  [['Khesari', 'Low'], 4],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Mesta', 'Very_High'], 9],
#  [['Groundnut', 'Low'], 11],
#  [['Other Kharif pulses', 'Low'], 9],
#  [['Potato', 'Very_High'], 7],
#  [['Onion', 'Very_High'], 5],
#  [['Citrus Fruit', 'Very_Low'], 2],
#  [['Wheat', 'High'], 4],
#  [['Rice', 'Low'], 7],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Urad', 'Very_Low'], 8],
#  [['Coconut ', 'Very_High'], 5],
#  [['Small millets', 'Low'], 10],
#  [['Barley', 'Low'], 7],
#  [['Cotton(lint)', 'Medium'], 11],
#  [['Potato', 'Very_High'], 4],
#  [['Rice', 'High'], 10],
#  [['Maize', 'Very_High'], 10],
#  [['Maize', 'Low'], 0],
#  [['Arecanut', 'Very_Low'], 5],
#  [['Cotton(lint)', 'High'], 10],
#  [['Sunflower', 'Low'], 11],
#  [['Dry ginger', 'High'], 9],
#  [['Rice', 'Medium'], 10],
#  [['Potato', 'Very_High'], 4],
#  [['Jute', 'Very_High'], 9],
#  [['Groundnut', 'High'], 10],
#  [['Onion', 'Very_High'], 7],
#  [['Sannhamp', 'Very_High'], 9],
#  [['Cashewnut', 'Low'], 7],
#  [['Urad', 'Very_Low'], 7],
#  [['Maize', 'Low'], 9],
#  [['Sesamum', 'Very_Low'], 11],
#  [['Coriander', 'Very_Low'], 2],
#  [['Small millets', 'Low'], 9],
#  [['Turmeric', 'Very_High'], 5],
#  [['Gram', 'Low'], 2],
#  [['Rice', 'Medium'], 7],
#  [['Turmeric', 'Low'], 2],
#  [['Gram', 'Very_Low'], 4],
#  [['Potato', 'Very_High'], 1],
#  [['Niger seed', 'Low'], 9],
#  [['Small millets', 'Very_Low'], 11],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Wheat', 'Medium'], 3],
#  [['Sesamum', 'Low'], 2],
#  [['Arhar/Tur', 'Low'], 7],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Jute', 'Very_High'], 9],
#  [['Linseed', 'Low'], 2],
#  [['Other Kharif pulses', 'Very_Low'], 10],
#  [['Groundnut', 'Very_Low'], 11],
#  [['Tobacco', 'High'], 1],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Sesamum', 'Low'], 5],
#  [['Tobacco', 'Medium'], 6],
#  [['Arhar/Tur', 'Very_Low'], 10],
#  [['Rapeseed &Mustard', 'Very_Low'], 4],
#  [['Cauliflower', 'Very_Low'], 3],
#  [['Onion', 'Very_High'], 1],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Soyabean', 'Low'], 11],
#  [['Wheat', 'Low'], 7],
#  [['Other  Rabi pulses', 'Low'], 8],
#  [['Dry ginger', 'Low'], 9],
#  [['Maize', 'Very_High'], 0],
#  [['Potato', 'Very_High'], 1],
#  [['Coriander', 'Very_Low'], 5],
#  [['Maize', 'Low'], 10],
#  [['Dry chillies', 'Very_Low'], 6],
#  [['Ash Gourd', 'Very_Low'], 7],
#  [['Gram', 'Very_Low'], 4],
#  [['Sugarcane', 'Very_High'], 11],
#  [['Wheat', 'Very_High'], 4],
#  [['Other  Rabi pulses', 'Very_Low'], 7],
#  [['Potato', 'Very_High'], 1],
#  [['Dry chillies', 'Medium'], 3],
#  [['Sugarcane', 'Very_High'], 7],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Wheat', 'High'], 4],
#  [['Urad', 'Low'], 7],
#  [['Tapioca', 'Very_High'], 9],
#  [['Groundnut', 'Low'], 0],
#  [['Sunflower', 'Medium'], 7],
#  [['Sugarcane', 'Very_High'], 2],
#  [['Masoor', 'Low'], 4],
#  [['Other Kharif pulses', 'Very_Low'], 9],
#  [['Other Kharif pulses', 'Very_Low'], 11],
#  [['Potato', 'Very_High'], 1],
#  [['Gram', 'Very_Low'], 7],
#  [['Rapeseed &Mustard', 'Very_Low'], 8],
#  [['Potato', 'Very_High'], 1],
#  [['Jowar', 'Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 3],
#  [['Linseed', 'Very_Low'], 7],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Small millets', 'Very_Low'], 9],
#  [['Guar seed', 'Low'], 4],
#  [['Sannhamp', 'Very_Low'], 1],
#  [['Dry ginger', 'Medium'], 11],
#  [['Barley', 'Medium'], 4],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Wheat', 'Very_High'], 4],
#  [['Pome Fruit', 'High'], 7],
#  [['Small millets', 'Medium'], 9],
#  [['Rice', 'Medium'], 10],
#  [['Other Kharif pulses', 'Low'], 10],
#  [['Dry chillies', 'Low'], 5],
#  [['Safflower', 'Very_Low'], 7],
#  [['Sunflower', 'Low'], 9],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Groundnut', 'Medium'], 11],
#  [['Linseed', 'Very_Low'], 8],
#  [['Sunflower', 'Low'], 7],
#  [['Rapeseed &Mustard', 'Very_Low'], 4],
#  [['Coriander', 'Very_Low'], 4],
#  [['Arhar/Tur', 'Low'], 9],
#  [['Gram', 'Low'], 4],
#  [['Moth', 'Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Arhar/Tur', 'Low'], 5],
#  [['Other Kharif pulses', 'Very_Low'], 11],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Maize', 'Low'], 7],
#  [['Rice', 'Low'], 7],
#  [['Rapeseed &Mustard', 'Low'], 8],
#  [['Rice', 'High'], 7],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Small millets', 'Low'], 9],
#  [['Maize', 'Low'], 11],
#  [['Dry chillies', 'Low'], 2],
#  [['Moong(Green Gram)', 'Very_Low'], 0],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Bajra', 'Low'], 9],
#  [['Gram', 'Low'], 4],
#  [['Peas & beans (Pulses)', 'Very_Low'], 2],
#  [['Barley', 'Low'], 4],
#  [['Barley', 'High'], 4],
#  [['Khesari', 'Very_Low'], 3],
#  [['Wheat', 'Very_High'], 4],
#  [['Small millets', 'Medium'], 10],
#  [['Turmeric', 'Very_High'], 6],
#  [['Sesamum', 'Very_Low'], 1],
#  [['Rapeseed &Mustard', 'Very_Low'], 8],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Other Cereals & Millets', 'Very_Low'], 11],
#  [['Pome Granet', 'Very_High'], 11],
#  [['Jowar', 'Low'], 9],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Other Kharif pulses', 'Low'], 10],
#  [['Rice', 'Very_High'], 8],
#  [['Dry ginger', 'Low'], 5],
#  [['Sesamum', 'Very_Low'], 7],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Rice', 'High'], 9],
#  [['Rice', 'Medium'], 2],
#  [['Rice', 'Medium'], 8],
#  [['Gram', 'Medium'], 7],
#  [['Linseed', 'Very_Low'], 8],
#  [['Linseed', 'Very_Low'], 4],
#  [['Arhar/Tur', 'Very_Low'], 10],
#  [['Tapioca', 'Very_High'], 5],
#  [['Bajra', 'Medium'], 9],
#  [['Dry ginger', 'Very_High'], 9],
#  [['Jowar', 'Very_Low'], 3],
#  [['Urad', 'Low'], 1],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Moth', 'Very_Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 10],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Gram', 'Low'], 5],
#  [['Dry chillies', 'Very_High'], 7],
#  [['Niger seed', 'Very_Low'], 11],
#  [['Rapeseed &Mustard', 'Low'], 8],
#  [['Arecanut', 'Medium'], 1],
#  [['Potato', 'Very_High'], 1],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 10],
#  [['Sweet potato', 'Very_High'], 3],
#  [['Sunflower', 'Very_Low'], 7],
#  [['Groundnut', 'Very_Low'], 10],
#  [['Coriander', 'Very_Low'], 1],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Sweet potato', 'Very_High'], 6],
#  [['Sunflower', 'Very_Low'], 3],
#  [['Urad', 'Very_Low'], 0],
#  [['Castor seed', 'Very_Low'], 7],
#  [['Dry ginger', 'Medium'], 2],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Ragi', 'Very_Low'], 7],
#  [['Maize', 'Medium'], 10],
#  [['Sunflower', 'Low'], 11],
#  [['Wheat', 'Low'], 7],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Pome Fruit', 'Very_High'], 7],
#  [['Wheat', 'Medium'], 4],
#  [['Niger seed', 'Very_Low'], 10],
#  [['Onion', 'Very_High'], 1],
#  [['Dry chillies', 'Very_Low'], 5],
#  [['Maize', 'Low'], 9],
#  [['Sunflower', 'Low'], 3],
#  [['Maize', 'Low'], 8],
#  [['Groundnut', 'Very_Low'], 10],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Wheat', 'High'], 4],
#  [['Jowar', 'Low'], 9],
#  [['Rice', 'Low'], 7],
#  [['Black pepper', 'Medium'], 8],
#  [['Peas & beans (Pulses)', 'Very_Low'], 3],
#  [['Jute', 'Medium'], 11],
#  [['Potato', 'High'], 10],
#  [['Soyabean', 'Low'], 11],
#  [['Other Fresh Fruits', 'Very_High'], 1],
#  [['Sunflower', 'Very_Low'], 7],
#  [['Arhar/Tur', 'Very_Low'], 5],
#  [['Garlic', 'Medium'], 3],
#  [['Small millets', 'Low'], 9],
#  [['Coriander', 'Low'], 5],
#  [['Sunflower', 'Medium'], 9],
#  [['Linseed', 'Very_Low'], 3],
#  [['Other  Rabi pulses', 'Very_Low'], 7],
#  [['Black pepper', 'Very_Low'], 7],
#  [['Sunflower', 'Very_Low'], 10],
#  [['Coconut ', 'Very_High'], 5],
#  [['Turmeric', 'Very_Low'], 2],
#  [['Sugarcane', 'Very_High'], 9],
#  [['Wheat', 'Medium'], 8],
#  [['Bajra', 'Very_Low'], 9],
#  [['Onion', 'High'], 4],
#  [['Sugarcane', 'Very_High'], 4],
#  [['Masoor', 'Very_Low'], 8],
#  [['Rice', 'Low'], 1],
#  [['Potato', 'Very_High'], 1],
#  [['Garlic', 'Medium'], 5],
#  [['Gram', 'Low'], 7],
#  [['Bajra', 'Low'], 9],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Arhar/Tur', 'Medium'], 9],
#  [['Jowar', 'Low'], 9],
#  [['Cotton(lint)', 'Low'], 6],
#  [['Potato', 'Very_High'], 4],
#  [['Wheat', 'Very_High'], 4],
#  [['Onion', 'Low'], 1],
#  [['Potato', 'Very_High'], 2],
#  [['Rice', 'Medium'], 7],
#  [['Urad', 'Low'], 7],
#  [['Bajra', 'Very_Low'], 10],
#  [['Coconut ', 'Very_High'], 7],
#  [['Onion', 'Very_High'], 10],
#  [['Rice', 'Very_High'], 11],
#  [['Rapeseed &Mustard', 'Very_Low'], 2],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Maize', 'Medium'], 10],
#  [['Sunflower', 'Low'], 11],
#  [['Sesamum', 'Very_Low'], 11],
#  [['Potato', 'Very_High'], 4],
#  [['Groundnut', 'Medium'], 11],
#  [['Wheat', 'Very_High'], 4],
#  [['Coconut ', 'Very_High'], 5],
#  [['Other Kharif pulses', 'Low'], 11],
#  [['Moong(Green Gram)', 'Low'], 10],
#  [['Maize', 'Low'], 4],
#  [['Sesamum', 'Very_Low'], 3],
#  [['Bajra', 'Very_Low'], 2],
#  [['Coriander', 'Very_Low'], 5],
#  [['Mesta', 'Very_High'], 9],
#  [['Turmeric', 'Low'], 1],
#  [['Horse-gram', 'Very_Low'], 0],
#  [['Groundnut', 'Low'], 10],
#  [['Maize', 'Very_High'], 3],
#  [['Turmeric', 'Low'], 3],
#  [['Banana', 'Very_High'], 6],
#  [['Groundnut', 'Low'], 10],
#  [['Sannhamp', 'Very_High'], 9],
#  [['Rice', 'Very_Low'], 7],
#  [['Sunflower', 'Medium'], 8],
#  [['Onion', 'Very_High'], 4],
#  [['Rice', 'Low'], 10],
#  [['Maize', 'High'], 1],
#  [['Linseed', 'Very_Low'], 4],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Jowar', 'Low'], 10],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Moth', 'Very_Low'], 9],
#  [['Onion', 'Very_High'], 10],
#  [['Sugarcane', 'Very_High'], 1],
#  [['Maize', 'Very_Low'], 9],
#  [['Urad', 'Very_Low'], 0],
#  [['Moong(Green Gram)', 'Very_Low'], 1],
#  [['Ragi', 'Very_High'], 7],
#  [['Gram', 'Low'], 7],
#  [['Coconut ', 'Very_High'], 1],
#  [['Onion', 'Very_High'], 7],
#  [['Khesari', 'Very_Low'], 4],
#  [['Sesamum', 'Low'], 10],
#  [['Urad', 'Very_Low'], 11],
#  [['Turmeric', 'Very_High'], 7],
#  [['Pome Fruit', 'Very_Low'], 4],
#  [['Arhar/Tur', 'Low'], 10],
#  [['Groundnut', 'Low'], 9],
#  [['Masoor', 'Very_Low'], 8],
#  [['Other  Rabi pulses', 'Very_Low'], 3],
#  [['Wheat', 'Very_High'], 4],
#  [['Soyabean', 'Low'], 11],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Other Vegetables', 'Very_High'], 5],
#  [['Khesari', 'Low'], 4],
#  [['Other  Rabi pulses', 'Low'], 4],
#  [['Other Kharif pulses', 'Low'], 9],
#  [['Groundnut', 'Low'], 7],
#  [['Gram', 'Low'], 3],
#  [['Tobacco', 'Low'], 1],
#  [['Dry chillies', 'Low'], 1],
#  [['Tapioca', 'Very_High'], 7],
#  [['Rice', 'Very_High'], 7],
#  [['Small millets', 'Low'], 11],
#  [['Rapeseed &Mustard', 'Very_Low'], 7],
#  [['Maize', 'Very_High'], 10],
#  [['Castor seed', 'Very_Low'], 10],
#  [['Potato', 'Very_High'], 7],
#  [['Barley', 'High'], 4],
#  [['Small millets', 'Low'], 9],
#  [['Rapeseed &Mustard', 'Medium'], 8],
#  [['Coriander', 'Low'], 1],
#  [['Bajra', 'Low'], 9],
#  [['Jowar', 'Low'], 9],
#  [['Potato', 'Very_High'], 8],
#  [['Maize', 'Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Bajra', 'Low'], 10],
#  [['Maize', 'High'], 9],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Sesamum', 'Very_Low'], 9],
#  [['Cashewnut', 'Low'], 5],
#  [['Turmeric', 'High'], 1],
#  [['Potato', 'Very_High'], 4],
#  [['Dry chillies', 'Very_Low'], 5],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Niger seed', 'Low'], 9],
#  [['Onion', 'Very_High'], 5],
#  [['Soyabean', 'Very_Low'], 9],
#  [['Arhar/Tur', 'Medium'], 5],
#  [['Cowpea(Lobia)', 'Medium'], 6],
#  [['Masoor', 'Very_Low'], 4],
#  [['Peas & beans (Pulses)', 'Low'], 4],
#  [['Dry chillies', 'Low'], 11],
#  [['Ragi', 'Medium'], 10],
#  [['Maize', 'Very_High'], 7],
#  [['Tomato', 'Very_High'], 5],
#  [['Masoor', 'Very_Low'], 6],
#  [['Groundnut', 'Very_Low'], 9],
#  [['Sesamum', 'Low'], 9],
#  [['Groundnut', 'Low'], 10],
#  [['Linseed', 'Low'], 4],
#  [['Maize', 'Medium'], 9],
#  [['Rice', 'High'], 11],
#  [['Rice', 'Very_Low'], 11],
#  [['Mesta', 'Very_High'], 9],
#  [['Urad', 'Very_Low'], 9],
#  [['Small millets', 'Very_Low'], 11],
#  [['Maize', 'Very_High'], 4],
#  [['Jute', 'Very_High'], 9],
#  [['Urad', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Very_Low'], 7],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Gram', 'Low'], 4],
#  [['Dry chillies', 'Medium'], 7],
#  [['Rice', 'High'], 7],
#  [['Barley', 'High'], 4],
#  [['Linseed', 'Very_Low'], 4],
#  [['Ragi', 'High'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Rapeseed &Mustard', 'Low'], 4],
#  [['Arhar/Tur', 'Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Coriander', 'Very_Low'], 7],
#  [['Sesamum', 'Very_Low'], 7],
#  [['Coconut ', 'Very_High'], 7],
#  [['Small millets', 'Very_Low'], 10],
#  [['Turmeric', 'Medium'], 1],
#  [['Wheat', 'Very_High'], 8],
#  [['Sweet potato', 'Very_High'], 5],
#  [['Rapeseed &Mustard', 'Very_Low'], 8],
#  [['Moong(Green Gram)', 'Very_Low'], 10],
#  [['Tapioca', 'Very_High'], 5],
#  [['Wheat', 'High'], 4],
#  [['Barley', 'Very_High'], 4],
#  [['Pump Kin', 'Very_Low'], 7],
#  [['Rapeseed &Mustard', 'Low'], 8],
#  [['Maize', 'Very_High'], 9],
#  [['Cotton(lint)', 'Very_Low'], 10],
#  [['Maize', 'Very_High'], 5],
#  [['Sweet potato', 'Very_High'], 9],
#  [['Urad', 'Very_Low'], 3],
#  [['Brinjal', 'Very_High'], 11],
#  [['Maize', 'High'], 4],
#  [['Guar seed', 'Very_Low'], 6],
#  [['Dry chillies', 'Very_Low'], 1],
#  [['Rice', 'Very_High'], 7],
#  [['Garlic', 'High'], 4],
#  [['Rice', 'Very_Low'], 4],
#  [['Gram', 'Very_Low'], 10],
#  [['Rice', 'High'], 2],
#  [['Tobacco', 'Low'], 4],
#  [['Rice', 'High'], 4],
#  [['Other Kharif pulses', 'Low'], 10],
#  [['Total foodgrain', 'Medium'], 5],
#  [['Potato', 'Very_High'], 4],
#  [['Sweet potato', 'Very_High'], 9],
#  [['Rice', 'High'], 10],
#  [['Tomato', 'Very_High'], 7],
#  [['Sannhamp', 'Very_Low'], 10],
#  [['Turmeric', 'Very_Low'], 1],
#  [['Colocosia', 'Very_High'], 11],
#  [['Turmeric', 'Very_High'], 4],
#  [['Urad', 'Low'], 9],
#  [['Castor seed', 'Very_Low'], 9],
#  [['Gram', 'Very_Low'], 3],
#  [['Pulses total', 'Very_Low'], 1],
#  [['Arecanut', 'Low'], 6],
#  [['Masoor', 'Very_Low'], 7],
#  [['Jowar', 'Very_Low'], 11],
#  [['Niger seed', 'Very_Low'], 10],
#  [['Groundnut', 'Low'], 9],
#  [['Rice', 'Very_High'], 10],
#  [['Gram', 'Very_Low'], 3],
#  [['Sunflower', 'Medium'], 5],
#  [['Sannhamp', 'Very_High'], 9],
#  [['Dry chillies', 'Very_High'], 10],
#  [['Black pepper', 'Very_High'], 5],
#  [['Pulses total', 'Very_Low'], 2],
#  [['Dry chillies', 'Low'], 5],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Niger seed', 'Very_Low'], 9],
#  [['Castor seed', 'Very_Low'], 10],
#  [['Barley', 'Medium'], 4],
#  [['Rice', 'High'], 10],
#  [['Safflower', 'Very_Low'], 7],
#  [['Barley', 'Low'], 4],
#  [['Rice', 'Low'], 9],
#  [['Castor seed', 'Very_Low'], 11],
#  [['Maize', 'Very_High'], 7],
#  [['Urad', 'Very_Low'], 10],
#  [['Other Kharif pulses', 'Very_Low'], 10],
#  [['Moong(Green Gram)', 'Low'], 4],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Sesamum', 'Very_Low'], 2],
#  [['Wheat', 'High'], 3],
#  [['Arhar/Tur', 'Low'], 11],
#  [['Peas & beans (Pulses)', 'Low'], 4],
#  [['Arhar/Tur', 'Very_Low'], 11],
#  [['Bajra', 'Very_Low'], 7],
#  [['Dry chillies', 'Low'], 1],
#  [['Maize', 'Medium'], 9],
#  [['Moth', 'Low'], 9],
#  [['Wheat', 'High'], 4],
#  [['Rice', 'Very_Low'], 10],
#  [['Other  Rabi pulses', 'Low'], 4],
#  [['Rice', 'Very_High'], 11],
#  [['Tobacco', 'Medium'], 5],
#  [['Maize', 'Medium'], 9],
#  [['Wheat', 'Very_High'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 8],
#  [['Rice', 'Medium'], 4],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Banana', 'Very_High'], 1],
#  [['Rice', 'Very_High'], 1],
#  [['Maize', 'Very_High'], 4],
#  [['Barley', 'High'], 3],
#  [['Dry chillies', 'Very_Low'], 10],
#  [['Rice', 'Very_High'], 11],
#  [['Urad', 'Low'], 9],
#  [['Guar seed', 'Low'], 9],
#  [['Masoor', 'Low'], 4],
#  [['Orange', 'Very_High'], 1],
#  [['Groundnut', 'Medium'], 7],
#  [['Urad', 'Very_Low'], 9],
#  [['Dry chillies', 'Very_Low'], 1],
#  [['Cowpea(Lobia)', 'Very_Low'], 3],
#  [['Maize', 'Very_High'], 11],
#  [['Maize', 'Very_High'], 4],
#  [['Rice', 'Low'], 9],
#  [['Maize', 'Medium'], 4],
#  [['Maize', 'High'], 1],
#  [['Horse-gram', 'Very_Low'], 4],
#  [['Other Fresh Fruits', 'Very_Low'], 2],
#  [['Gram', 'Low'], 7],
#  [['Orange', 'High'], 7],
#  [['Wheat', 'Low'], 8],
#  [['Sugarcane', 'Very_High'], 5],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Moth', 'Very_Low'], 9],
#  [['Sweet potato', 'Very_High'], 2],
#  [['Small millets', 'Medium'], 5],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Jute', 'Very_High'], 9],
#  [['Sweet potato', 'Low'], 4],
#  [['Dry chillies', 'Very_Low'], 3],
#  [['Barley', 'High'], 3],
#  [['Rice', 'Medium'], 0],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Sunflower', 'Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Soyabean', 'Low'], 10],
#  [['Bajra', 'Very_Low'], 10],
#  [['Cotton(lint)', 'Very_Low'], 10],
#  [['Maize', 'Medium'], 0],
#  [['Masoor', 'Low'], 4],
#  [['Wheat', 'Medium'], 8],
#  [['Masoor', 'Low'], 4],
#  [['Turmeric', 'High'], 1],
#  [['Other Kharif pulses', 'Very_Low'], 11],
#  [['Sunflower', 'Very_Low'], 11],
#  [['Moong(Green Gram)', 'Very_Low'], 7],
#  [['Sweet potato', 'Very_High'], 8],
#  [['Turmeric', 'Medium'], 3],
#  [['Maize', 'High'], 7],
#  [['Tomato', 'Very_High'], 7],
#  [['Gram', 'Very_Low'], 7],
#  [['Rapeseed &Mustard', 'Very_Low'], 7],
#  [['Onion', 'Very_High'], 7],
#  [['Oilseeds total', 'Medium'], 5],
#  [['Barley', 'Low'], 8],
#  [['Moong(Green Gram)', 'Low'], 1],
#  [['Bajra', 'Low'], 10],
#  [['Peas & beans (Pulses)', 'Medium'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Coriander', 'Very_Low'], 5],
#  [['Sugarcane', 'Very_High'], 2],
#  [['Wheat', 'Very_High'], 4],
#  [['Gram', 'Very_Low'], 7],
#  [['Banana', 'Very_High'], 5],
#  [['Dry ginger', 'Very_High'], 6],
#  [['Groundnut', 'High'], 7],
#  [['Rice', 'Medium'], 8],
#  [['Moong(Green Gram)', 'Low'], 1],
#  [['Black pepper', 'Low'], 5],
#  [['Gram', 'Low'], 4],
#  [['Sugarcane', 'Very_High'], 4],
#  [['Wheat', 'Medium'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 1],
#  [['Sweet potato', 'Very_High'], 1],
#  [['Banana', 'Very_High'], 1],
#  [['Water Melon', 'Very_Low'], 2],
#  [['Potato', 'Very_High'], 1],
#  [['Bajra', 'Low'], 9],
#  [['Moong(Green Gram)', 'Very_Low'], 11],
#  [['Other Kharif pulses', 'Very_Low'], 10],
#  [['Moth', 'Very_Low'], 9],
#  [['Sugarcane', 'Very_High'], 2],
#  [['Safflower', 'Low'], 7],
#  [['Tapioca', 'Very_High'], 1],
#  [['Horse-gram', 'Very_Low'], 7],
#  [['Rapeseed &Mustard', 'Medium'], 4],
#  [['Moong(Green Gram)', 'Very_Low'], 9],
#  [['Coriander', 'Very_Low'], 7],
#  [['Potato', 'Very_High'], 7],
#  [['Rice', 'Low'], 4],
#  [['Rice', 'High'], 6],
#  [['Groundnut', 'Very_Low'], 11],
#  [['Sesamum', 'Very_Low'], 10],
#  [['Cotton(lint)', 'Very_Low'], 9],
#  [['Rice', 'Very_High'], 11],
#  [['Tobacco', 'High'], 1],
#  [['Masoor', 'Low'], 4],
#  [['Maize', 'High'], 11],
#  [['Rice', 'Very_High'], 9],
#  [['Barley', 'Very_High'], 8],
#  [['Mesta', 'Very_High'], 9],
#  ...]

# %%
# clusters, dictionary key= cluster number, value = list of crops of that cluster
clusters = dict()
total = 0
for _, (crop, cluster) in enumerate(ans):
    if cluster not in clusters.keys():
        clusters[cluster] = []
    
    clusters[cluster].append(crop[0])

for i in clusters.keys():
    total += len(clusters[i])

# distribution of clusters
cluster_sizes = dict()
for i in clusters.keys():
    if i not in cluster_sizes.keys():
        cluster_sizes[i] = 0
    
    cluster_sizes[i] = len(clusters[i])/total

# converting to list for plotting
labels = list(cluster_sizes.keys())
distribution = []
for i in labels:
    distribution.append(cluster_sizes[i])

# %%
labels
# Out:
# [5, 0, 11, 9, 7, 4, 3, 8, 2, 10, 1, 6]

# %%
distribution
# Out:
# [0.08588606289234034,
#  0.025463440511626537,
#  0.08335150747104418,
#  0.15421885591347145,
#  0.1306769620700834,
#  0.13962453213875217,
#  0.049152692228345764,
#  0.048221390468892754,
#  0.04500309451533995,
#  0.12071556983289618,
#  0.0941911526332852,
#  0.023494739323922077]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.pie(distribution, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax.axis('equal')

plt.tight_layout()
plt.show()

# %%
crop_distribution = []
unique_crops = len(set(DF.Crop))
for i in labels:
    print("Cluster {} len {}".format(i, len(clusters[i])))
    crop_distribution.append(len(clusters[i])/unique_crops)

# %%
fig2, ax2 = plt.subplots()
ax2.pie(crop_distribution, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax2.axis('equal')

plt.tight_layout()
plt.show()

# %%
# Out:
# 124
